# %% [markdown]
# ## Jupyter Data Science Workflow
# #### From exploratory analysis to reproducible science
# ##### Jake VanderPlas
# ##### University of Washington eScience Institute

# %%
 URL = 'https://data.seattle.gov/api/views/65db-xm6k/rows.csv?accessType=DOWNLOAD'

# %%
from urllib.request import urlretrieve
urlretrieve(URL, 'Fremont.csv')
# Out:
# ('Fremont.csv', <http.client.HTTPMessage at 0x7fb00a051de0>)

# %%
import pandas as pd
data = pd.read_csv('Fremont.csv', index_col = 'Date', parse_dates=True, usecols=['Date', 'Fremont Bridge East Sidewalk', 'Fremont Bridge West Sidewalk'])
data.head()
# Out:
#                      Fremont Bridge East Sidewalk  \
# Date
# 2022-08-01 00:00:00                           7.0
# 2022-08-01 01:00:00                           5.0
# 2022-08-01 02:00:00                           0.0
# 2022-08-01 03:00:00                           2.0
# 2022-08-01 04:00:00                           2.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2022-08-01 00:00:00                          16.0
# 2022-08-01 01:00:00                           7.0
# 2022-08-01 02:00:00                           3.0
# 2022-08-01 03:00:00                           3.0
# 2022-08-01 04:00:00                           8.0

# %%
# %matplotlib inline
data.resample('W').sum().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')
data.columns = ['East', 'West']
data.resample('W').sum().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data['Total'] = data['West'] + data['East']
ax = data.resample('D').sum().rolling(360).sum().plot()
ax.set_ylim(0, None)
# Out:
# (0.0, 1246993.45)

# %%
data.groupby(data.index.time).mean().plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
pivoted = data.pivot_table('Total', index=data.index.time, columns=data.index.date)
pivoted.iloc[:5, :5]
# Out:
#           2012-10-03  2012-10-04  2012-10-05  2012-10-06  2012-10-07
# 00:00:00        13.0        18.0        11.0        15.0        11.0
# 01:00:00        10.0         3.0         8.0        15.0        17.0
# 02:00:00         2.0         9.0         7.0         9.0         3.0
# 03:00:00         5.0         3.0         4.0         3.0         6.0
# 04:00:00         7.0         8.0         9.0         5.0         3.0

# %%
pivoted.plot(legend=False, alpha=0.01)
# Out:
# <AxesSubplot:xlabel='time'>
