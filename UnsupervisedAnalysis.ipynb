# %% [markdown]
# # Unsupservised Analysis of Days of Week
#
# Treating crossings each day as features to learn about the relationships between various days.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

from sklearn.decomposition import PCA
from sklearn.mixture import GaussianMixture

# %% [markdown]
# # Get Data

# %%
from jupyterworkflow.data import get_fremont_data
data = get_fremont_data()

# %%
pivoted = data.pivot_table('Total', index=data.index.time, columns=data.index.date)
pivoted.plot(legend=False, alpha=0.01)
# Out:
# <AxesSubplot:xlabel='time'>

# %% [markdown]
# # Principal Component Analysis

# %%
X = pivoted.fillna(0).T.values
X.shape
# Out:
# (3650, 24)

# %%
X2 = PCA(2, svd_solver='full').fit_transform(X)
X2.shape
# Out:
# (3650, 2)

# %%
plt.scatter(X2[:, 0], X2[:, 1])

# %% [markdown]
# # Unsupervised Clustering

# %%
qmm = GaussianMixture(2).fit(X)
labels = qmm.predict(X)

# %%
plt.scatter(X2[:, 0], X2[:, 1], c=labels, cmap='rainbow')
plt.colorbar()

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

pivoted.T[labels == 1].T.plot(legend=False, alpha=0.1, ax=ax[1])
pivoted.T[labels == 0].T.plot(legend=False, alpha=0.1, ax=ax[0])

ax[0].set_title('Purple Cluster')
ax[1].set_title('Red Cluster')
# Out:
# Text(0.5, 1.0, 'Red Cluster')

# %% [markdown]
# ## Comparing with Day of Week

# %%
dayofweek = pd.DatetimeIndex(pivoted.columns).dayofweek

# %%
plt.scatter(X2[:, 0], X2[:, 1], c=dayofweek, cmap='rainbow')
plt.colorbar()

# %% [markdown]
# # Analyzing Outliner
# The following points are weekdays with a holiday-like pattern

# %%
dates = pd.DatetimeIndex(pivoted.columns)
dates[(labels == 0) & (dayofweek < 5)]
# Out:
# DatetimeIndex(['2012-11-22', '2012-11-23', '2012-12-25', '2013-01-01',
#                '2013-05-27', '2013-07-04', '2013-07-05', '2013-09-02',
#                '2013-11-28', '2013-11-29', '2013-12-20', '2013-12-25',
#                '2014-01-01', '2014-04-23', '2014-05-26', '2014-07-04',
#                '2014-09-01', '2014-11-27', '2014-12-25', '2015-01-01',
#                '2015-05-25', '2015-07-03', '2015-09-07', '2015-11-26',
#                '2015-11-27', '2015-12-25', '2016-01-01', '2016-05-30',
#                '2016-07-04', '2016-09-05', '2016-11-24', '2016-11-25',
#                '2016-12-26', '2017-01-02', '2017-02-06', '2017-05-29',
#                '2017-07-04', '2017-09-04', '2017-11-23', '2017-11-24',
#                '2017-12-25', '2018-01-01', '2018-05-28', '2018-07-04',
#                '2018-09-03', '2018-11-22', '2018-11-23', '2018-12-25',
#                '2019-01-01', '2019-02-04', '2019-02-05', '2019-02-08',
#                '2019-02-11', '2019-02-12', '2019-05-27', '2019-07-04',
#                '2019-07-05', '2019-09-02', '2019-11-28', '2019-12-25',
#                '2020-01-01', '2020-03-30', '2020-03-31', '2020-05-25',
#                '2020-07-03', '2020-08-14', '2020-09-07', '2020-11-26',
#                '2020-11-27', '2020-12-23', '2020-12-24', '2020-12-25',
#                '2020-12-28', '2020-12-31', '2021-01-01', '2021-01-18',
#                '2021-02-05', '2021-02-15', '2021-05-31', '2021-07-05',
#                '2021-09-06', '2021-11-25', '2021-11-26', '2021-12-23',
#                '2021-12-24', '2021-12-28', '2021-12-29', '2021-12-30',
#                '2021-12-31', '2022-01-03', '2022-01-17', '2022-02-21',
#                '2022-05-30', '2022-07-04', '2022-09-05'],
#               dtype='datetime64[ns]', freq=None)
